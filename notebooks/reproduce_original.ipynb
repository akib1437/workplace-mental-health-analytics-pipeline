# %% [markdown]
# # Reproduce the original workplace analysis
#
# This notebook runs the same pipeline as the command-line interface. It exports aggregate-only results.

# %%
import sys, subprocess
subprocess.run([sys.executable, "run_pipeline.py", "--config", "config/workplace_config.yaml"], check=True)

# %%
import pandas as pd
from pathlib import Path
out = Path("outputs")
display(pd.read_csv(out / "reliability.csv"))
display(pd.read_csv(out / "severity_distribution.csv"))
display(pd.read_csv(out / "verification_log.csv"))

# %% [markdown]
# Do not export or display respondent-level records in this notebook or in the manuscript supplement.
