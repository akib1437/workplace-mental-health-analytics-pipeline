# %% [markdown]
# # Independent technical portability demonstration
#
# This is a technical run on a public student dataset, not a workplace replication. The ready-to-run configuration is already supplied in `config/zenodo_config.yaml`.

# %% [markdown]
# ## Before running
#
# Place the original downloaded files in `data/external_raw/` with exactly these names: `demographic.csv`, `phq9.csv`, and `gad7.csv`. Do not open, edit, or re-save the raw CSVs in Excel.

# %%
from pathlib import Path
import pandas as pd

project_root = Path.cwd()
if not (project_root / 'data' / 'external_raw').exists():
    project_root = project_root.parent
data_dir = project_root / 'data' / 'external_raw'

print('Project folder:', project_root)
print('Files found:', [file.name for file in data_dir.iterdir()] if data_dir.exists() else 'FOLDER NOT FOUND')

for file_name in ['demographic.csv', 'phq9.csv', 'gad7.csv']:
    path = data_dir / file_name
    print(f'\n{file_name} | exists: {path.exists()}')
    if path.exists():
        df = pd.read_csv(path, nrows=5)
        print('Columns:', df.columns.tolist())
        display(df)
# Out:
# Project folder: g:\AIUB\13th sem\Thesis\JSCDM_disclosure_controlled_pipeline_starter\jsdcm_pipeline_starter
# Files found: ['demographic.csv', 'gad7.csv', 'phq9.csv', 'README.md']
#
# demographic.csv | exists: True
# Columns: ['export_id', 'gender', 'age', 'edu', 'smoke', 'drink']
#    export_id  gender   age                edu         smoke  \
# 0      61793  female  19.0  bachelor's degree  never smokes
# 1      61809  female  18.0  bachelor's degree  never smokes
# 2      61737    male  40.0    master's degree  never smokes
# 3      61738  female  23.0  bachelor's degree  never smokes
# 4      61739  female  21.0  bachelor's degree  never smokes
#
#                                          drink
# 0                                 never drinks
# 1                                 never drinks
# 2  drinks occasionally (less than once a week)
# 3                                 never drinks
# 4                                 never drinks
# phq9.csv | exists: True
# Columns: ['export_id', 'score', 'question1', 'time1', 'question2', 'time2', 'question3', 'time3', 'question4', 'time4', 'question5', 'time5', 'question6', 'time6', 'question7', 'time7', 'question8', 'time8', 'question9', 'time9']
#    export_id  score  question1  time1  question2  time2  question3  time3  \
# 0      61793      0          0   2.47          0   1.23          0   1.12
# 1      61809      0          0   8.22          0   7.08          0   1.24
# 2      61737      0          0   1.88          0   1.65          0   1.00
# 3      61738      0          0   1.74          0   2.02          0   2.26
# 4      61739      2          1   5.54          0   2.57          0   1.30
#
#    question4  time4  question5  time5  question6  time6  question7  time7  \
# 0          0   1.73          0   4.74          0   1.32          0   0.16
# 1          0   1.08          0   1.77          0   1.26          0   1.05
# 2          0   1.18          0   0.81          0   1.29          0   4.17
# 3          0   0.76          0   0.59          0   0.62          0   0.54
# 4          0   2.19          0   1.08          1   3.33          0   3.13
#
#    question8  time8  question9  time9
# 0          0  12.99          0   4.00
# 1          0   2.07          0   3.76
# 2          0   1.29          0   4.58
# 3          0   0.71          0   3.37
# 4          0   3.63          0   4.31
# gad7.csv | exists: True
# Columns: ['export_id', 'score', 'question1', 'time1', 'question2', 'time2', 'question3', 'time3', 'question4', 'time4', 'question5', 'time5', 'question6', 'time6', 'question7', 'time7']
#    export_id  score  question1  time1  question2  time2  question3  time3  \
# 0      61793      0          0   2.19          0   8.10          0   0.95
# 1      61809      0          0   5.96          0   3.84          0   1.53
# 2      61737      0          0   5.03          0   1.72          0   3.47
# 3      61738      0          0   1.91          0   0.83          0   0.46
# 4      61739      0          0   1.51          0   2.37          0   0.89
#
#    question4  time4  question5  time5  question6  time6  question7  time7
# 0          0   0.81          0   0.72          0   0.80          0   3.28
# 1          0   1.26          0   1.16          0   0.91          0   2.64
# 2          0   1.85          0   2.38          0   1.84          0   7.37
# 3          0   0.41          0   0.45          0   0.41          0   6.51
# 4          0   0.50          0   0.51          0   0.54          0   2.57

# %% [markdown]
# When all three files show `exists: True`, stop using the notebook and run the official command below from PowerShell in the project root.

# %%
# Run in PowerShell instead of this notebook:
# .\.venv\Scripts\python.exe run_pipeline.py --config config\zenodo_config.yaml
